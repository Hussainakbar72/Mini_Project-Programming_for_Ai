# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
model_name = "t5-small"

tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]

# %%
text = """
Artificial Intelligence is revolutionizing industries by automating tasks,
analyzing data, and improving decisions. While organizations invest heavily
in AI, ethical and privacy concerns still exist.
"""

input_text = "summarize: " + text

# %%
inputs = tokenizer.encode(
    input_text,
    return_tensors="pt",
    max_length=512,
    truncation=True
)

# %%
summary_ids = model.generate(
    inputs,
    max_length=60,
    min_length=20,
    length_penalty=2.0,
    num_beams=4,
    early_stopping=True
)

# %%
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print("Summary:", summary)
# Out:
# Summary: AI systems are automating processes, analyzing data, and improving decision-making. organizations investing heavily in AI research, though ethical and privacy challenges remain.
